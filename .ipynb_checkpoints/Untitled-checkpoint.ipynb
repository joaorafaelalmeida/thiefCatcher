# %%
import argparse
import scipy.stats as stats
import numpy as np
import matplotlib.pyplot as plt

# %%
def extractStats(data):
    nSamp,nCols=data.shape

    M1=np.mean(data,axis=0) # por cada coluna = 4
    Md1=np.median(data,axis=0)
    Std1=np.std(data,axis=0)
    #S1=stats.skew(data)
    ##K1=stats.kurtosis(data)
    #p=[75,90,95,98]
    #Pr1=np.array(np.percentile(data,p,axis=0)).T.flatten()
        
    #features=np.hstack((M1,Md1,Std1,S1,Pr1))
    features=np.hstack((M1,Md1,Std1))
    return(features)

def extratctSilenceActivity(data,threshold=0):
    if(data[0]<=threshold):
        s=[1]
        a=[]
    else:
        s=[]
        a=[1]
    for i in range(1,len(data)):
        if(data[i-1]>threshold and data[i]<=threshold):
            s.append(1)
        elif(data[i-1]<=threshold and data[i]>threshold):
            a.append(1)
        elif (data[i-1]<=threshold and data[i]<=threshold):
            s[-1]+=1
        else:
            a[-1]+=1
    return(s,a)
    
def extractStatsSilenceActivity(data):
    features=[]
    nSamples,nMetrics=data.shape
    silence_features=np.array([])
    activity_features=np.array([])
    for c in range(nMetrics):
        silence,activity=extratctSilenceActivity(data[:,c],threshold=0)
        
        if len(silence)>0:
            silence_faux=np.array([len(silence),np.mean(silence),np.std(silence)])
        else:
            silence_faux=np.zeros(3)
        silence_features=np.hstack((silence_features,silence_faux))
        
        if len(activity)>0:
            activity_faux=np.array([len(activity),np.mean(activity),np.std(activity)])
        else:
            activity_faux=np.zeros(3)
        activity_features=np.hstack((activity_features,activity_faux))	   
    features=np.hstack((silence_features,activity_features))
    return(features)

# %% [markdown]
# ### slidingMultObsWindow
# This function returns all the extracted features. The return is a dict containing the windows size (as key) and the list of features extracted from that windows (as value).
# Index of the features in the array:
# 1. Mean (4 columns: Up Size, Up Count, Down Size, Down Count) [0, 1, 2, 3]
# 2. Median (4 columns: Up Size, Up Count, Down Size, Down Count) [4, 5, 6, 7]
# 3. Standard deviation (4 columns: Up Size, Up Count, Down Size, Down Count) [8, 9, 10, 11]
# 4. Silence (12 columns)
# 5. Activity (12 columns)

# %%
def slidingMultObsWindow(data,lengthObsWindow,slidingValue, filterIndex=None):
    nSamples,nMetrics=data.shape
    #Fix windows
    results = {}
    for s in np.arange(max(lengthObsWindow),nSamples,slidingValue):
        features=np.array([])
        for oW in lengthObsWindow:
            if oW not in results:
                results[oW] = []
            subdata=data[s-oW:s,1:]
            faux=extractStats(subdata)
            faux2=extractStatsSilenceActivity(subdata)
            features=np.hstack((faux,faux2))#np.hstack((features,faux,faux2))
            #print(('{} '*len(features)).format(*features))
            if filterIndex:
                features = features[filterIndex]
            results[oW].append(features)
    
    for oW in lengthObsWindow:
        if oW in results:
            results[oW] = np.array(results[oW])
    return results

# %%
fileInput="results/normal/tcpWindows17_12_2020_19_59_38.txt"
bruteInput="results/brute/tcpWindows17_12_2020_21_44_24.txt"
smoothInput="results/smooth/tcpWindows17_12_2020_21_59_40.txt"
intelligentInput="results/intelligent/tcpWindows17_12_2020_23_43_16.txt"

window=8
obsWindows=[8]#,32,64]#,10]
slidingValue=2
featuresIndex=[2, 10]

data=np.loadtxt(fileInput,dtype=int)
normalTraffic = slidingMultObsWindow(data,obsWindows,slidingValue, featuresIndex)

dataBrute=np.loadtxt(bruteInput,dtype=int)
bruteTraffic = slidingMultObsWindow(dataBrute,obsWindows,slidingValue, featuresIndex)

dataSmooth=np.loadtxt(smoothInput,dtype=int)
smoothTraffic = slidingMultObsWindow(dataSmooth,obsWindows,slidingValue, featuresIndex)

dataIntelligent=np.loadtxt(intelligentInput,dtype=int)
intelligentTraffic = slidingMultObsWindow(dataIntelligent,obsWindows,slidingValue, featuresIndex)

# %%
# Loading relevant libraries and the dataset
import warnings
warnings.filterwarnings('ignore',category=FutureWarning)
warnings.filterwarnings('ignore',category=RuntimeWarning)

import numpy as np
import matplotlib.pyplot as plt
from scipy.io import loadmat
import matplotlib
# %matplotlib inline

# %%
Xtrain=normalTraffic[window]
XBrute=bruteTraffic[window]
Xsmooth=smoothTraffic[window]
Xintelligent=intelligentTraffic[window]

# %%
plt.figure(figsize=(15,15))
plt.subplot(2, 2, 1)
plt.scatter(Xtrain[:, 0], Xtrain[:, 1],marker="x")

plt.subplot(2, 2, 2)
plt.scatter(XBrute[:, 0], XBrute[:, 1],marker="x")

plt.subplot(2, 2, 3)
plt.scatter(Xsmooth[:, 0], Xsmooth[:, 1],marker="x")

plt.subplot(2, 2, 4)
plt.scatter(Xintelligent[:, 0], Xintelligent[:, 1],marker="x")

# %%
plt.figure(figsize=(10,4))
plt.subplot(1, 2, 1)
plt.hist(Xtrain[:, 0], 20, density=1, color='g')

plt.subplot(1, 2, 2)
plt.hist(Xtrain[:, 1], 20, density=1, color='g')
# Out:
# (array([0.01256937, 0.0013966 , 0.00810026, 0.00614503, 0.00083796,
#         0.00279319, 0.00027932, 0.00167592, 0.00055864, 0.00083796,
#         0.00027932, 0.        , 0.00083796, 0.00027932, 0.        ,
#         0.        , 0.00027932, 0.00083796, 0.        , 0.00111728]),
#  array([  0.        ,  25.75633417,  51.51266834,  77.26900252,
#         103.02533669, 128.78167086, 154.53800503, 180.29433921,
#         206.05067338, 231.80700755, 257.56334172, 283.3196759 ,
#         309.07601007, 334.83234424, 360.58867841, 386.34501259,
#         412.10134676, 437.85768093, 463.6140151 , 489.37034928,
#         515.12668345]),
#  <BarContainer object of 20 artists>)

# %%
from sklearn.cluster import KMeans
from numpy import sqrt, random, array, argsort
from sklearn.preprocessing import scale
from sklearn.datasets import load_boston
import matplotlib.pyplot as plt

# %%
x = scale(Xtrain[:, 0])
kmeans = KMeans(n_clusters = 1).fit(x)
print(kmeans)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-2b7f0c41fee1> in <module>
#       1 x = scale(Xtrain[:, 0])
# ----> 2 kmeans = KMeans(n_clusters = 1).fit(x)
#       3 print(kmeans)
#
# ~\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py in fit(self, X, y, sample_weight)
#    1028             Fitted estimator.
#    1029         """
# -> 1030         X = self._validate_data(X, accept_sparse='csr',
#    1031                                 dtype=[np.float64, np.float32],
#    1032                                 order='C', copy=self.copy_x,
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     418                     f"requires y to be passed, but the target y is None."
#     419                 )
# --> 420             X = check_array(X, **check_params)
#     421             out = X
#     422         else:
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     617             # If input is 1D raise error
#     618             if array.ndim == 1:
# --> 619                 raise ValueError(
#     620                     "Expected 2D array, got 1D array instead:\narray={}.\n"
#     621                     "Reshape your data either using array.reshape(-1, 1) if "
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[-0.98113992 -0.98118609 -0.98143479 -0.9792647  -0.97853434 -0.97853434
#  -0.97780398 -0.97851335 -0.97924371 -0.97924371 -0.97997407 -0.98143479
#  -0.97384787 -0.96991904 -0.96991904 -0.96991904 -0.97750596 -0.98143479
#  -0.98143479 -0.98143479 -0.98126899 -0.98126899 -0.98126899 -0.98126899
#  -0.98143479 -0.97988803 -0.97022965 -0.97022965 -0.94099744 -0.51173709
#   0.06291619  1.23805608  1.46903329  1.03822618  0.45467111  1.5702993
#   1.31008987  2.32145716  2.82402523  0.75072796  1.46334047  0.69885356
#   0.91730133  0.98212072  0.5190907   0.5209932   0.13102116  0.46486361
#   0.71565602  0.71507992  0.88388633  0.76845912  0.7683269   0.52012013
#   0.19375336  1.00491717  0.75846704  0.75846704  0.58871725 -0.64601304
#   0.01553623  0.01553623  0.01112888 -0.06601008 -0.98135189 -0.96830931
#   1.4427393   1.95000749  2.200866    2.43888027  0.02774876 -0.47951943
#  -0.73037794 -0.98135189  0.72576982  1.94755302  2.44927005  2.70004567
#   1.24136263  0.52002044  0.01830341  0.01817119 -0.23026749 -0.4812257
#   0.02092158  0.27221033  0.96399291  1.27532854  1.21528167  1.02506712
#   0.57503035  0.27434894  0.53127175  0.77379515  0.78393518  0.77207104
#   0.07304783 -0.23028533 -0.23268838 -0.48096126 -0.22990441 -0.23118044
#  -0.48066324 -0.22960639 -0.22744364 -0.47715835 -0.22727784 -0.47833469
#  -0.48069577 -0.23235678 -0.48223729 -0.29826962 -0.48324888 -0.48318277
#  -0.48318277 -0.66715044 -0.73302969 -0.85698197  1.0426671   1.55028472
#   1.80391147  1.68338748 -0.21626159 -0.72387922 -0.97750596 -0.98143479
#  -0.98126899 -0.98126899 -0.98126899 -0.98126899 -0.98143479 -0.98143479
#  -0.98143479 -0.98143479 -0.98143479 -0.98143479 -0.98143479 -0.97332319
#  -0.97332319].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
center = kmeans.cluster_centers_
print(center)
distance = sqrt((Xtrain - center)**2)

# %%
order_index = argsort(distance, axis = 0)
indexes = order_index[-10:]

# %%
#values = Xtrain[indexes]
x = scale(Xtrain[:, 1])
values = x[indexes]
print(values)
x_ax = range(len(x))
plt.plot(x_ax, x)
plt.scatter(indexes, values, color='r')
plt.show()

# %%
Xtrain = slidingMultObsWindow(data,obsWindows,slidingValue, [2, 11])[window]
BootI = slidingMultObsWindow(dataIntelligent,obsWindows,slidingValue, [2, 11])[window]

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager
from sklearn import svm

#xx, yy = np.meshgrid(np.linspace(-5, 5, 500), np.linspace(-5, 5, 500))
xx, yy = np.meshgrid(np.linspace(-5, 5, 500), np.linspace(-5, 5, 500))
# Generate train data
#X = 0.3 * np.random.randn(100, 2)
#X_train = np.r_[X + 2, X - 2]
# Generate some regular novel observations
#X = 0.3 * np.random.randn(20, 2)
#X_test = np.r_[X + 2, X - 2]
# Generate some abnormal novel observations
#X_outliers = np.random.uniform(low=-4, high=4, size=(20, 2))

# fit the model
clf = svm.OneClassSVM(nu=0.1, kernel="rbf", gamma=0.1)
clf.fit(Xtrain)

y_pred_train = clf.predict(Xtrain)
y_pred_test = clf.predict(BootI)
#y_pred_outliers = clf.predict(BootI)

n_error_train = y_pred_train[y_pred_train == -1].size
n_error_test = y_pred_test[y_pred_test == -1].size
#n_error_outliers = y_pred_outliers[y_pred_outliers == 1].size

# plot the line, the points, and the nearest vectors to the plane
Z = clf.decision_function(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

plt.title("Novelty Detection")
plt.contourf(xx, yy, Z, levels=np.linspace(Z.min(), 0, 7), cmap=plt.cm.PuBu)
a = plt.contour(xx, yy, Z, levels=[0], linewidths=2, colors='darkred')
plt.contourf(xx, yy, Z, levels=[0, Z.max()], colors='palevioletred')

s = 40
b1 = plt.scatter(X_train[:, 0], X_train[:, 1], c='white', s=s, edgecolors='k')
b2 = plt.scatter(X_test[:, 0], X_test[:, 1], c='blueviolet', s=s,
                 edgecolors='k')
c = plt.scatter(X_outliers[:, 0], X_outliers[:, 1], c='gold', s=s,
                edgecolors='k')
plt.axis('tight')
plt.xlim((-5, 5))
plt.ylim((-5, 5))
plt.legend([a.collections[0], b1, b2, c],
           ["learned frontier", "training observations",
            "new regular observations", "new abnormal observations"],
           loc="upper left",
           prop=matplotlib.font_manager.FontProperties(size=11))
plt.xlabel(
    "error train: %d/200 ; errors novel regular: %d/40 ; "
    "errors novel abnormal: %d/40"
    % (n_error_train, n_error_test, n_error_outliers))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-d4c87146d108> in <module>
#      32
#      33 plt.title("Novelty Detection")
# ---> 34 plt.contourf(xx, yy, Z, levels=np.linspace(Z.min(), 0, 7), cmap=plt.cm.PuBu)
#      35 a = plt.contour(xx, yy, Z, levels=[0], linewidths=2, colors='darkred')
#      36 plt.contourf(xx, yy, Z, levels=[0, Z.max()], colors='palevioletred')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in contourf(data, *args, **kwargs)
#    2575 @_copy_docstring_and_deprecators(Axes.contourf)
#    2576 def contourf(*args, data=None, **kwargs):
# -> 2577     __ret = gca().contourf(
#    2578         *args, **({"data": data} if data is not None else {}),
#    2579         **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in contourf(self, *args, **kwargs)
#    6338     def contourf(self, *args, **kwargs):
#    6339         kwargs['filled'] = True
# -> 6340         contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6341         self._request_autoscale_view()
#    6342         return contours
#
# ~\anaconda3\lib\site-packages\matplotlib\contour.py in __init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, nchunk, locator, transform, *args, **kwargs)
#     814         self._transform = transform
#     815
# --> 816         kwargs = self._process_args(*args, **kwargs)
#     817         self._process_levels()
#     818
#
# ~\anaconda3\lib\site-packages\matplotlib\contour.py in _process_args(self, corner_mask, *args, **kwargs)
#    1428             self._corner_mask = corner_mask
#    1429
# -> 1430             x, y, z = self._contour_args(args, kwargs)
#    1431
#    1432             _mask = ma.getmask(z)
#
# ~\anaconda3\lib\site-packages\matplotlib\contour.py in _contour_args(self, args, kwargs)
#    1486             args = args[1:]
#    1487         elif Nargs <= 4:
# -> 1488             x, y, z = self._check_xyz(args[:3], kwargs)
#    1489             args = args[3:]
#    1490         else:
#
# ~\anaconda3\lib\site-packages\matplotlib\contour.py in _check_xyz(self, args, kwargs)
#    1517
#    1518         if z.ndim != 2:
# -> 1519             raise TypeError(f"Input z must be 2D, not {z.ndim}D")
#    1520         if z.shape[0] < 2 or z.shape[1] < 2:
#    1521             raise TypeError(f"Input z must be at least a (2, 2) shaped array, "
#
# TypeError: Input z must be 2D, not 1D
